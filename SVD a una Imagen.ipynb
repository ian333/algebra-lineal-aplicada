# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')
imagen= Image.open("../Imagenes/imagen_ejemplo_frida_bredesen.jpg")
plt.imshow(imagen)

# %%
imagen_gr= imagen.convert('LA')
plt.imshow(imagen_gr)

# %%
imagen_mat=np.array(list(imagen_gr.getdata(band=0)),float)
print(imagen_mat)
# Out:
# [236. 236. 235. ... 195. 195. 193.]

# %%
imagen_mat.shape=(imagen_gr.size[1],imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 238. 238. 238.]
#  ...
#  [217. 216. 216. ... 197. 196. 194.]
#  [216. 216. 216. ... 196. 195. 193.]
#  [216. 216. 216. ... 195. 195. 193.]]

# %%
print(imagen_mat.shape)
# Out:
# (3456, 3693)

# %%
plt.imshow(imagen_mat,cmap='gray')

# %%
imagen_mat_2=imagen_mat/10
print(imagen_mat_2)
# Out:
# [[23.6 23.6 23.5 ... 23.9 23.9 23.9]
#  [23.6 23.6 23.5 ... 23.9 23.9 23.9]
#  [23.6 23.6 23.5 ... 23.8 23.8 23.8]
#  ...
#  [21.7 21.6 21.6 ... 19.7 19.6 19.4]
#  [21.6 21.6 21.6 ... 19.6 19.5 19.3]
#  [21.6 21.6 21.6 ... 19.5 19.5 19.3]]

# %%
plt.imshow(imagen_mat_2)

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 24.4
# 244.0

# %%
U,D,V= np.linalg.svd(imagen_mat)

# %%
print(imagen_mat.shape)
print(U.shape)
print(D.shape)
print(D)
print(V.shape)
# Out:
# (3456, 3693)
# (3456, 3456)
# (3456,)
# [5.52488148e+05 9.57804210e+04 7.98680291e+04 ... 8.44290478e-01
#  8.39771123e-01 7.98984953e-01]
# (3693, 3693)

# %% [markdown]
# ## ¿Cuantos valores singulares se tendran que utilizar para que la imagen sea reconocible?

# %%
imagen_reconstruida=np.matrix(U[:,:1])*np.diag(D[:1])*np.matrix(V[:1,:])
plt.imshow(imagen_reconstruida,cmap='gray')

# %%
fig,ax = plt.subplots(4,2,figsize=(30,30))
for a in range(4):
    for b in range(4):
        i=(2**(a*2))*2**b
        imagen_reconstruida=np.matrix(U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
        ax[a,b].imshow(imagen_reconstruida,cmap='gray')
        ax[a,b].set_title(f'Imagen con {i} valores singulares')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_87/1186409636.py in <module>
# ----> 1 fig,ax = plt.subplots(4,2,figsize=(30,30))
#       2 for a in range(4):
#       3     for b in range(4):
#       4         i=(2**(a*2))*2**b
#       5         imagen_reconstruida=np.matrix(U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e4a76e78-c18a-4fc7-af6b-dc86cc664138' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
